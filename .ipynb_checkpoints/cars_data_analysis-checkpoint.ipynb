# %%
import pandas as pd
df = pd.read_csv('cars.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5076 entries, 0 to 5075
# Data columns (total 18 columns):
# City mpg                   5076 non-null int64
# Classification             5076 non-null object
# Driveline                  5076 non-null object
# Engine Type                5076 non-null object
# Fuel Type                  5076 non-null object
# Height                     5076 non-null int64
# Highway mpg                5076 non-null int64
# Horsepower                 5076 non-null int64
# Hybrid                     5076 non-null bool
# ID                         5076 non-null object
# Length                     5076 non-null int64
# Make                       5076 non-null object
# Model Year                 5076 non-null object
# Number of Forward Gears    5076 non-null int64
# Torque                     5076 non-null int64
# Transmission               5076 non-null object
# Width                      5076 non-null int64
# ...

# %%
df.head()
# Out:
#    City mpg          Classification          Driveline  \
# 0        18  Automatic transmission    All-wheel drive
# 1        22  Automatic transmission  Front-wheel drive
# 2        21     Manual transmission  Front-wheel drive
# 3        21  Automatic transmission    All-wheel drive
# 4        21  Automatic transmission    All-wheel drive
#
#                                     Engine Type Fuel Type  Height  \
# 0          Audi 3.2L 6 cylinder 250hp 236ft-lbs  Gasoline     140
# 1  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo  Gasoline     140
# 2  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo  Gasoline     140
# 3  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo  Gasoline     140
# 4  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo  Gasoline     140
#
#    Highway mpg  Horsepower  Hybrid                          ID  Length  Make  \
# 0           25         250   False            2009 Audi A3 3.2     143  Audi
# 1           28         200   False       2009 Audi A3 2.0 T AT     143  Audi
# ...

# %%
sum(df.duplicated())
# Out:
# 18

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
# 30      False
#         ...
# 5046    False
# 5047    False
# 5048    False
# 5049    False
# 5050    False
# 5051    False
# 5052    False
# 5053    False
# 5054    False
# 5055    False
# 5056    False
# 5057    False
# 5058    False
# 5059    False
# 5060    False
# 5061    False
# 5062    False
# 5063    False
# 5064    False
# 5065    False
# 5066    False
# 5067    False
# 5068    False
# 5069    False
# 5070    False
# 5071    False
# 5072    False
# 5073    False
# 5074    False
# 5075    False
# ...

# %%
sum(df.duplicated())
# Out:
# 0

# %%
df.shape
# Out:
# (5058, 18)

# %%
import pandas as pd
# %matplotlib inline

df_graph = pd.read_csv('cars.csv')
df_graph.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5076 entries, 0 to 5075
# Data columns (total 18 columns):
# City mpg                   5076 non-null int64
# Classification             5076 non-null object
# Driveline                  5076 non-null object
# Engine Type                5076 non-null object
# Fuel Type                  5076 non-null object
# Height                     5076 non-null int64
# Highway mpg                5076 non-null int64
# Horsepower                 5076 non-null int64
# Hybrid                     5076 non-null bool
# ID                         5076 non-null object
# Length                     5076 non-null int64
# Make                       5076 non-null object
# Model Year                 5076 non-null object
# Number of Forward Gears    5076 non-null int64
# Torque                     5076 non-null int64
# Transmission               5076 non-null object
# Width                      5076 non-null int64
# ...

# %%
df_graph.hist(figsize=(10,8))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\histograms.py in _unsigned_subtract(a, b)
#     287     try:
# --> 288         dt = signed_to_unsigned[dt.type]
#     289     except KeyError:
#
# KeyError: <class 'numpy.bool_'>
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-0870096c4b9c> in <module>
# ----> 1 df_graph.hist(figsize=(10,8))
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, **kwds)
#    2411     for i, col in enumerate(com._try_sort(data.columns)):
#    2412         ax = _axes[i]
# -> 2413         ax.hist(data[col].dropna().values, bins=bins, **kwds)
# ...

# %%
df_graph['Horsepower'].hist()

# %%
sum(df_graph['Horsepower']>=600)
# Out:
# 32

# %%
df_graph['Horsepower'].plot(kind='hist')

# %%
df_graph['Horsepower'].value_counts().plot(kind='pie',figsize=(10,8))

# %%
df_graph['Fuel Type'].value_counts().plot(kind='bar',figsize=(15,8))

# %%
df_graph['Fuel Type'].value_counts()
# Out:
# Gasoline                  4591
# E85                        456
# Diesel fuel                 27
# Compressed natural gas       2
# Name: Fuel Type, dtype: int64

# %%
df_graph[df_graph['Fuel Type'] == 'Compressed natural gas']
# Out:
#      City mpg          Classification          Driveline  \
# 871        24  Automatic transmission  Front-wheel drive
# 966        24  Automatic transmission  Front-wheel drive
#
#                                      Engine Type               Fuel Type  \
# 871  Honda 1.8L 4 Cylinder 113 hp 109 ft-lbs CNG  Compressed natural gas
# 966  Honda 1.8L 4 Cylinder 113 hp 109 ft-lbs CNG  Compressed natural gas
#
#      Height  Highway mpg  Horsepower  Hybrid                         ID  \
# 871     155           36         113   False  2010 Honda Civic GX Sedan
# 966     155           36         113   False  2011 Honda Civic GX Sedan
#
#      Length   Make              Model Year  Number of Forward Gears  Torque  \
# 871     151  Honda  2010 Honda Civic Sedan                        5     109
# 966     151  Honda  2011 Honda Civic Sedan                        5     109
#
#           Transmission  Width  Year
# 871  5 Speed Automatic    216  2010
# 966  5 Speed Automatic    216  2011

# %%
sum(df_graph.duplicated())
# Out:
# 18

# %%
df_graph.drop_duplicates(inplace=True)

# %%
sum(df_graph.duplicated())
# Out:
# 0

# %%
df_graph['Fuel Type'].value_counts()
# Out:
# Gasoline                  4574
# E85                        456
# Diesel fuel                 26
# Compressed natural gas       2
# Name: Fuel Type, dtype: int64

# %%
df_graph[df_graph['Fuel Type'] == 'Compressed natural gas']
# Out:
#      City mpg          Classification          Driveline  \
# 871        24  Automatic transmission  Front-wheel drive
# 966        24  Automatic transmission  Front-wheel drive
#
#                                      Engine Type               Fuel Type  \
# 871  Honda 1.8L 4 Cylinder 113 hp 109 ft-lbs CNG  Compressed natural gas
# 966  Honda 1.8L 4 Cylinder 113 hp 109 ft-lbs CNG  Compressed natural gas
#
#      Height  Highway mpg  Horsepower  Hybrid                         ID  \
# 871     155           36         113   False  2010 Honda Civic GX Sedan
# 966     155           36         113   False  2011 Honda Civic GX Sedan
#
#      Length   Make              Model Year  Number of Forward Gears  Torque  \
# 871     151  Honda  2010 Honda Civic Sedan                        5     109
# 966     151  Honda  2011 Honda Civic Sedan                        5     109
#
#           Transmission  Width  Year
# 871  5 Speed Automatic    216  2010
# 966  5 Speed Automatic    216  2011

# %%
df_graph_a = df_graph[df_graph['Classification'] == 'Automatic transmission']
df_graph_m = df_graph[df_graph['Classification'] == 'Manual transmission']

# %%
df_graph_a.head(20)
# Out:
#     City mpg          Classification          Driveline  \
# 0         18  Automatic transmission    All-wheel drive
# 1         22  Automatic transmission  Front-wheel drive
# 3         21  Automatic transmission    All-wheel drive
# 6         17  Automatic transmission    All-wheel drive
# 7         13  Automatic transmission    All-wheel drive
# 8         14  Automatic transmission    All-wheel drive
# 10        21  Automatic transmission    All-wheel drive
# 11        17  Automatic transmission    All-wheel drive
# 12        20  Automatic transmission  Front-wheel drive
# 13        18  Automatic transmission    All-wheel drive
# 14        12  Automatic transmission    All-wheel drive
# 15        12  Automatic transmission    All-wheel drive
# 16        12  Automatic transmission    All-wheel drive
# 17        12  Automatic transmission    All-wheel drive
# 20        18  Automatic transmission   Rear-wheel drive
# 23        18  Automatic transmission   Rear-wheel drive
# ...

# %%
df_graph_m.head(20)
# Out:
#      City mpg       Classification          Driveline  \
# 2          21  Manual transmission  Front-wheel drive
# 5          16  Manual transmission    All-wheel drive
# 9          22  Manual transmission    All-wheel drive
# 18         18  Manual transmission   Rear-wheel drive
# 19         18  Manual transmission   Rear-wheel drive
# 21         18  Manual transmission   Rear-wheel drive
# 22         18  Manual transmission   Rear-wheel drive
# 24         18  Manual transmission   Rear-wheel drive
# 25         20  Manual transmission   Rear-wheel drive
# 41         18  Manual transmission   Rear-wheel drive
# 42         18  Manual transmission   Rear-wheel drive
# 43         18  Manual transmission   Rear-wheel drive
# 44         21  Manual transmission  Front-wheel drive
# 47         21  Manual transmission  Front-wheel drive
# 59         20  Manual transmission  Front-wheel drive
# 61         21  Manual transmission  Front-wheel drive
# ...

# %%
ind = df_graph_a['Driveline'].value_counts().index
df_graph_a['Driveline'].value_counts()[ind].plot(kind='pie',figsize=(10,8))

# %%
df_graph_m['Driveline'].value_counts()[ind].plot(kind='pie',figsize=(10,8))

# %%
df_graph_m['Driveline'].describe()
# Out:
# count                  1123
# unique                    4
# top       Front-wheel drive
# freq                    498
# Name: Driveline, dtype: object
